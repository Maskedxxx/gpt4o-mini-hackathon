# %%
import os
import sys

os.chdir('/Users/mask/Documents/Проеты_2025/gpt_4_mini_hackaton/app_talebot_v3')
# Получаем текущую рабочую директорию
current_dir = os.getcwd()

# Добавляем родительскую директорию текущей директории в путь Python
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir)

# %%
from tests.llm_agent_final_rewrite import LLMService
from config.config import load_config, Config

# Инициализация
config = load_config()
llm_service = LLMService(config=config)
# Out:
# 2025-01-27 17:45:46 - config.config - INFO - Приложение запускается в режиме: development

# %%
# Пример резюме и вакансии
sample_resume = {
  "title": "Руководитель разработки программного обеспечения",
  "skills": "Павел Дуров — опытный руководитель разработки программного обеспечения с 18-летним стажем в технологической отрасли. Эксперт в управлении удаленными и офисными командами. Специалист в языках программирования: Ruby, Python, JavaScript, TypeScript, Elixir. Опыт в области data science и машинного обучения позволяет успешно внедрять масштабируемые AI-решения.",
  "skill_set": [],
  "experience": [
    {
      "description": "- - Павел превратил инженерное подразделение в ключевой источник дохода для Data Kernel, быстро расширив клиентскую базу с момента ее создания до надежного сообщества.- Он возглавил интеграцию передовых технологий искусственного интеллекта и использование масштабируемых векторных баз данных, что значительно расширило возможности продукта и его позиционирование на рынке.- Под его руководством команда добилась существенного роста в развитии навыков, сосредоточив внимание на достижении стратегических целей проекта, которые существенно повлияли на направление развития компании.- Ной также сыграл решающую роль в определении долгосрочных стратегических инициатив компании, особенно в области внедрения технологий искусственного интеллекта, которые установили новые стандарты в отрасли.",      
      "position": "Директор разработки программного обеспечения (удалённо)"
    },
    {
      "description": "Ной основал Innovapet, стартап, специализирующийся на инновационных решениях Интернета вещей для ухода за домашними животными, включая революционный ошейник с GPS-трекингом, который значительно повысил безопасность питомца и спокойствие владельца.- Он отвечал за разработку продукта от концепции до воплощения в жизнь, тесно сотрудничая с инженерными командами и партнерами по маркетингу, чтобы обеспечить успешный выход на рынок.- Успешно создал консультативный совет, открыл производственные мощности за рубежом и провел компанию через успешный начальный этап финансирования, продемонстрировав свои лидерские качества и предпринимательскую хватку.- Создана начальная версия продукта с использованием MongoDB",      
      "position": "Основатель и генеральный директор (удалённо)"
    },
    {
      "description": "- Руководил разработкой стратегии и операционной деятельностью в тесном сотрудничестве с руководителями высшего звена, играя ключевую роль в формировании технологической траектории компании.- Руководил различными командами, работающими в разных часовых поясах в Северной Америке и Европе, создавая атмосферу прозрачности и взаимного уважения, что повышало производительность и моральный дух команды.- Его инициативы в области подбора персонала, наставничества и удержания талантливых специалистов сыграли решающую роль в формировании культуры постоянного совершенствования и высокой производительности.",
      "position": "Старший менеджер разработки программного обеспечения (удалённо)"
    },
    {
      "description": "- Ноа сыграл важную роль в разработке и реализации стратегических планов, которые укрепили межведомственную координацию и доверие, что привело к улучшению результатов проекта.- Он руководил несколькими инженерными командами, способствуя формированию культуры, сочетающей продуктивность с инновациями, и внедрил систему постановки целей, которая соответствовала долгосрочным целям компании.- Был очень практичным менеджером, использующим ruby on rails и react для создания нового продукта.",
      "position": "Менеджер инженерного отдела (удалённо)"
    },
    {
      "description": "- Руководил формированием и развитием высокопроизводительной инженерной команды, которая сыграла ключевую роль в увеличении выручки компании на 500% в течение двух лет.- Его лидерство в области интеграции анализа данных в процессы принятия бизнес-решений привело к разработке инструмента прогнозного моделирования, который произвел революцию в анализе поведения клиентов.",
      "position": "Менеджер инженерного отдела (удалённо)"
    },
    {
      "description": "Разработал и оптимизировал центральный API, значительно улучшив его функциональность. Внедрил стратегию кеширования, что позволило существенно сократить время отклика и снизить нагрузку на систему.",
      "position": "Старший разработчик программного обеспечения (удалённо)"
    },
    {
      "description": "Руководил технологической стратегией компании после получения финансирования серии A. Руководил разработкой продукта с использованием React и Angular, значительно улучшив производительность платформы.",
      "position": "Технический директор (CTO)"
    }
  ],
  "employments": [
    "Полная занятость"
  ],
  "schedules": [
    "Полный день"
  ],
  "languages": [
    {
      "name": "Русский",
      "level": {
        "name": "Родной"
      }
    },
    {
      "name": "Английский",
      "level": {
        "name": "A1 — Начальный"
      }
    },
    {
      "name": "Итальянский",
      "level": {
        "name": "A1 — Начальный"
      }
    }
  ],
  "relocation": {
    "type": {
      "name": "не могу переехать"
    }
  },
  "salary": 100000,
  "professional_roles": [
    {
      "name": "DevOps-инженер"
    },
    {
      "name": "Дата-сайентист"
    },
    {
      "name": "Директор по информационным технологиям (CIO)"
    }
  ]
}

# %%
sample_resume_1 = {
    "title": "Руководитель разработки программного обеспечения",
    "skills": (
        "Павел Дуров — опытный руководитель разработки программного обеспечения с 18-летним "
        "стажем в технологической отрасли. Обладает экспертизой в управлении распределёнными "
        "командами, а также в области машинного обучения и анализа данных. Имеет опыт внедрения "
        "скalable ML-решений, включая создание конвейеров обработки данных, интеграцию моделей "
        "компьютерного зрения и работы с большими объёмами неструктурированных данных."
    ),
    "skill_set": [],
    "experience": [
        {
            "description": (
                "Внедрил продвинутую аналитику для голосовых и текстовых данных, сократив время анализа вдвое. "
                "Управлял распределённой командой (инженеры, аналитики), обеспечив эффективную коммуникацию. "
                "Разработал внутренние инструменты для автоматизации сбора и обработки данных."
            ),
            "position": "Директор AI-направления (удалённо)",
            "start": "2021-01-01",
            "end": None
        },
        {
            "description": (
                "Интегрировал модели машинного обучения в инфраструктуру компании, расширив возможности персонализации. "
                "Спроектировал модульную архитектуру, упрощающую подключение новых AI-решений. "
                "Установил ключевые метрики эффективности (KPI) для data-проектов совместно с бизнес-отделом."
            ),
            "position": "Руководитель ML-команды (удалённо)",
            "start": "2018-01-01",
            "end": "2021-01-01"
        },
        {
            "description": (
                "Инициировал использование гибких методологий (Scrum, Kanban) для быстрой разработки AI-функционала. "
                "Создал модели прогнозной аналитики, оптимизировав рекомендательные системы. "
                "Организовал программу наставничества, повысив общий уровень знаний команды в ML."
            ),
            "position": "Старший менеджер по разработке аналитических решений",
            "start": "2015-01-01",
            "end": "2018-01-01"
        }
    ],
    "employments": [
        "Полная занятость"
    ],
    "schedules": [
        "Полный день"
    ],
    "languages": [
        {
            "name": "Русский",
            "level": {
                "name": "Родной"
            }
        },
        {
            "name": "Английский",
            "level": {
                "name": "A1 — Начальный"
            }
        },
        {
            "name": "Итальянский",
            "level": {
                "name": "A1 — Начальный"
            }
        }
    ],
    "relocation": {
        "type": {
            "name": "не могу переехать"
        }
    },
    "salary": 50000,
    "professional_roles": [
        {
            "name": "DevOps-инженер"
        },
        {
            "name": "Дата-сайентист"
        },
        {
            "name": "Директор по информационным технологиям (CIO)"
        }
    ]
}

# %%
gap_data = {
  "recommendations": [
    {
      "section": "title",
      "recommendation_type": "update",
      "details": "1. Change the current title 'Руководитель разработки программного обеспечения' to 'Руководитель отдела разработки' to align with the job description."
    },
    {
      "section": "skills",
      "recommendation_type": "add",
      "details": "1. Revise the current skills section. 2. Add the following skills that are mentioned in the job description but are missing from your resume: .Net, .Net Core, Golang, Docker, Kafka, MS SQL, PostgreSQL, ClickHouse, Redis."
    },
    {
      "section": "skill_set",
      "recommendation_type": "add",
      "details": "1. Create a skill set section. 2. Include relevant skills such as Scrum, Kanban, and SAFe methodologies, which are important for the role."
    },
    {
      "section": "experience",
      "recommendation_type": "update",
      "details": "1. For the position 'Директор разработки программного обеспечения (удалённо)': Emphasize experience in managing teams of at least 15 people and highlight any relevant metrics or improvements in team performance."
    },
    {
      "section": "experience",
      "recommendation_type": "update",
      "details": "1. For the position 'Основатель и генеральный директор (удалённо)': Highlight any experience related to team building, hiring, and onboarding processes, as well as any metrics related to team growth or product success."
    },
    {
      "section": "experience",
      "recommendation_type": "update",
      "details": "1. For the position 'Старший менеджер разработки программного обеспечения (удалённо)': Include specific examples of how you organized the development process and any methodologies used (Scrum/Kanban)."
    },
    {
      "section": "experience",
      "recommendation_type": "update",
      "details": "1. For the position 'Менеджер инженерного отдела (удалённо)': Add details about how you evaluated and formed expectations for clients, and any metrics that demonstrate the success of your projects."
    },
    {
      "section": "experience",
      "recommendation_type": "update",
      "details": "1. For the position 'Менеджер инженерного отдела (удалённо)': Highlight your role in improving development speed and quality, and provide specific examples of initiatives you led."
    },
    {
      "section": "experience",
      "recommendation_type": "update",
      "details": "1. For the position 'Старший разработчик программного обеспечения (удалённо)': Emphasize any experience with .Net or similar technologies, and detail how your contributions improved system performance."
    },
    {
      "section": "experience",
      "recommendation_type": "update",
      "details": "1. For the position 'Технический директор (CTO)': Highlight your leadership in technology strategy and any relevant metrics that demonstrate the impact of your work on the company's growth."
    },
    {
      "section": "professional_roles",
      "recommendation_type": "add",
      "details": "1. Analyze the current professional roles. 2. Add 'Руководитель отдела разработки' to the list of roles to better match the job description."
    }
  ]
}

# %%
gap_data_1 = {
    "recommendations": [
    {
      "section": "title",
      "recommendation_type": "update",
      "details": [
        "1. Change the current title 'Руководитель разработки программного обеспечения' to 'ML Engineer' or 'Senior ML Engineer' to align with the job description.",
        "2. Ensure that the new title reflects a focus on machine learning and AI technologies."
      ]
    },
    {
      "section": "skills",
      "recommendation_type": "add",
      "details": [
        "1. Add missing skills from the job description: Python, Git, Linux, Bash.",
        "2. Include specific frameworks mentioned in the job description such as TensorFlow, PyTorch, and Keras.",
        "3. Highlight knowledge of modern algorithms and optimization methods relevant to machine learning."
      ]
    },
    {
      "section": "skill_set",
      "recommendation_type": "add",
      "details": [
        "1. Create a skill set section that lists technical competencies related to ML engineering.",
        "2. Include skills like model deployment, data preprocessing techniques, and experience with reproducible pipelines."
      ]
    },
    {
      "section": "experience[0]",
      "recommendation_type": "update",
      "details": [
        "1. For position 'Директор AI-направления (удалённо)', emphasize any direct involvement with machine learning models and their production use.",
        "2. Specify any tools or frameworks used during implementation of advanced analytics for voice/text data.",
        "3. Quantify results achieved through your leadership in terms of performance improvements or efficiency gains."
      ]
    },
    {
      "section": "experience[1]",
      "recommendation_type": "update",
      "details": [
        "1. For position 'Руководитель ML-команды (удалённо)', explicitly mention which DL frameworks were utilized for integrating ML models into infrastructure.",
        "2. Detail how you established key performance indicators (KPIs) specifically for machine learning projects.",
        "3. Highlight collaboration with business departments to enhance product personalization using ML."
      ]
    },
    {
      "section": "experience[2]",
      "recommendation_type": "update",
      "details": [
        "'Старший менеджер по разработке аналитических решений': Focus on specific AI functionalities developed under agile methodologies.",
        "'Include examples of predictive modeling work done and its impact on recommendation systems.'"
      ]
    },
    {
      "section": "professional_roles",
      "recommendation_type": "add",
      "details": [
        "1.Add roles directly related to Machine Learning Engineering such as 'ML Engineer' or 'Data Scientist'.",
        "2.Remove unrelated roles if they do not contribute to the targeted position."
      ]
    }
  ]
}

# %%
from models.gap_analysis import ResumeGapAnalysis

gap_result = ResumeGapAnalysis(**gap_data_1)
print(gap_result)
# Out:
# recommendations=[Recommendation(section='title', recommendation_type='update', details=["1. Change the current title 'Руководитель разработки программного обеспечения' to 'ML Engineer' or 'Senior ML Engineer' to align with the job description.", '2. Ensure that the new title reflects a focus on machine learning and AI technologies.']), Recommendation(section='skills', recommendation_type='add', details=['1. Add missing skills from the job description: Python, Git, Linux, Bash.', '2. Include specific frameworks mentioned in the job description such as TensorFlow, PyTorch, and Keras.', '3. Highlight knowledge of modern algorithms and optimization methods relevant to machine learning.']), Recommendation(section='skill_set', recommendation_type='add', details=['1. Create a skill set section that lists technical competencies related to ML engineering.', '2. Include skills like model deployment, data preprocessing techniques, and experience with reproducible pipelines.']), Recommendation(s
# ...

# %%
final_resume = llm_service.final_resume_rewrite(
    parsed_resume=sample_resume_1, 
    gap_analysis=gap_result, 
)

if final_resume:
    print(final_resume.model_dump_json(indent=2))
else:
    print("Не удалось получить итоговый рерайт.")
# Out:
# 2025-01-27 17:46:20 - tests.llm_agent_final_rewrite - INFO - Финальный рерайт выполнен успешно.
# {
#   "title": "ML Engineer",
#   "skills": "Павел Дуров — опытный ML-инженер с 18-летним стажем в технологической отрасли. Обладает экспертизой в управлении распределёнными командами, а также в области машинного обучения и анализа данных. Имеет опыт внедрения масштабируемых ML-решений, включая создание конвейеров обработки данных, интеграцию моделей компьютерного зрения и работы с большими объёмами неструктурированных данных. Знание Python, Git, Linux, Bash и современных алгоритмов оптимизации.",
#   "skill_set": [
#     "Python",
#     "Git",
#     "Linux",
#     "Bash",
#     "TensorFlow",
#     "PyTorch",
#     "Keras",
#     "Моделирование и развертывание моделей машинного обучения",
#     "Техники предварительной обработки данных"
#   ],
#   "experience": [
#     {
# ...

# %%
# Примечание к результату выше:
# Надо доработать промпт так как: 1 - Применять ключевые навыки в вакансии к опыту резюме. 
# 2 - Если обьекты в experience не требуют рерайта оставлять пустыми. 
# 3 - более усиленное полсвечивание ключевых навыков из gap анализа которые должны быть учтены в рерайте

# %%
from typing import Any
from pydantic import BaseModel

class MarkdownConverter:
    """
    Конвертер для преобразования объектов Pydantic в Markdown формат.
    
    Attributes:
        indent_char: Символ для отступов (по умолчанию пробел)
        indent_size: Размер отступа (по умолчанию 2)
    """
    
    def __init__(self, indent_char: str = " ", indent_size: int = 2):
        self.indent_char = indent_char
        self.indent_size = indent_size
    
    def _get_indent(self, level: int) -> str:
        """Возвращает отступ для текущего уровня вложенности."""
        return self.indent_char * (level * self.indent_size)
    
    def _convert_value(self, value: Any, level: int = 0) -> str:
        """
        Преобразует значение в Markdown формат.
        
        Args:
            value: Значение для преобразования
            level: Текущий уровень вложенности
            
        Returns:
            str: Отформатированная строка в Markdown
        """
        if isinstance(value, BaseModel):
            return self.convert(value, level)
        elif isinstance(value, list):
            if not value:
                return "[]"
            result = []
            for item in value:
                indent = self._get_indent(level + 1)
                converted = self._convert_value(item, level + 1)
                result.append(f"{indent}- {converted}")
            return "\n" + "\n".join(result)
        elif isinstance(value, dict):
            if not value:
                return "{}"
            result = []
            for key, val in value.items():
                indent = self._get_indent(level + 1)
                converted = self._convert_value(val, level + 1)
                result.append(f"{indent}**{key}**: {converted}")
            return "\n" + "\n".join(result)
        else:
            return str(value)
    
    def convert(self, model: BaseModel, level: int = 0) -> str:
        """
        Преобразует модель Pydantic в Markdown.
        
        Args:
            model: Модель Pydantic для преобразования
            level: Уровень вложенности
            
        Returns:
            str: Строка в формате Markdown
        """
        result = []
        indent = self._get_indent(level)
        
        for field_name, field_value in model:
            if field_value is not None:  # Пропускаем None значения
                converted = self._convert_value(field_value, level)
                result.append(f"{indent}**{field_name}**: {converted}")
        
        return "\n".join(result)

# Пример использования:
converter = MarkdownConverter()
markdown_text = converter.convert(final_resume)
print(markdown_text)
# Out:
# **title**: Руководитель разработки программного обеспечения
# **skills**: Павел Дуров — опытный руководитель разработки программного обеспечения с 18-летним стажем в технологической отрасли. Эксперт в управлении удаленными и офисными командами. Имеет практический опыт работы в области data science и машинного обучения, что позволяет ему эффективно внедрять масштабируемые AI-решения. Кроме того, его опыт в руководстве командами и разработке стратегических инициатив подтверждает его стратегическое видение и навыки выстраивания партнерских отношений.
# **skill_set**:
#   - Руководство командами
#   - Опыт в области data science и машинного обучения
#   - Управление удаленными командами
# **experience**:
# ...

# %%
# Сохраняем в файл или используем как нужно
with open('rewrite.md', 'w', encoding='utf-8') as f:
    f.write(markdown_text)
